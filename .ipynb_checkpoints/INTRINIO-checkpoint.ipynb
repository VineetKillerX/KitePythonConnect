# %%
import logging
import os
import pandas as pd
from common import indicators
import sys
import numpy as np
import time
from datetime import datetime, timedelta
#from common.get_api_data import *
from common.get_api_data_alpha_vantage import get_data,get_price
from yahoo_fin.stock_info import *



logging.basicConfig(level=logging.INFO)
import common.application as ap
import pytz
#from simulator import place_order as simulator
from common.SlackUtil import sendMessage

app_properties = ap.app_properties
token_mappings = ap.token_mappings
csv_mapping = ap.csv_mapping
keys = ap.keys
api_key = app_properties['api_key']
api_secret = app_properties['api_secret']
token ="INFY"
os.makedirs(token, exist_ok=True)
file_name = "trades.csv"
tz = pytz.timezone('Asia/Kolkata')
logger = logging.getLogger('algo_tester')
# global define
profit = 0.019
stop_loss = 0.0095
historical_data = ""
rsi = 0.00
rsi_slope = 0.00
last_close = 0.00
last_high = 0.00
last_low = 0.00
last_price = get_price(token, 0.00)
current_price = 0.00
holding = ""
order_id = ""
swing = False
flag = ''
interval_int=15
interval=str(interval_int)+"min"

rsi_count=0
sma_triggered=False
extrema_triggered=False
activation=''
def getDateTime():
    datetime_obj_hour_fwd = datetime.now(tz)+timedelta(seconds=75)
    return datetime_obj_hour_fwd


datetime_obj_hour_fwd = getDateTime() + timedelta(hours=1)
from_date = str(datetime_obj_hour_fwd - timedelta(days=14)).split(" ")[0]

# %%
last_price
# Out:
# 715.5

# %%
import traceback

# %%
def reprocess_df(df):
    df = historical_data
    df = indicators.RSI(df,period=14)
    df=indicators.SMA(df, "close", "sma_7", 7)
    df=indicators.SMA(df, "close", "sma_50", 50)
    df['RSI_Trend'] = df['RSI_14'].diff()
    window = 20
    no_of_std = 2
    rolling_mean = df['close'].rolling(window).mean()
    rolling_std = df['close'].rolling(window).std()
    df['ub'] = rolling_mean + (rolling_std * no_of_std)
    df['mb'] = rolling_mean
    df['lb'] = rolling_mean - (rolling_std * no_of_std)
    df['ub_tren']= df['ub'].diff().round(0)
    df['lb_tren']= df['lb'].diff().round(0)
    df['3_ub_point']=df.ub.shift(2).apply(str)+","+    df.ub.shift(1).apply(str)+","+    df.ub.apply(str)
    df['3_lb_point']=df.lb.shift(2).apply(str)+","+    df.lb.shift(1).apply(str)+","+    df.lb.apply(str)
    df['divergence_angle']=df['3_ub_point'].apply(compute_angle)+df['3_lb_point'].apply(compute_angle)
    df['divergence_col']=df.apply(lambda x:  "divergence" if 25 <=x['divergence_angle']<=100 and x['ub_tren']>=0 and x['lb_tren']<=0 and x['ub_tren']!=x['lb_tren'] else '',axis=1)
    df['rsi_indication']=df.RSI_14.apply(lambda x:1 if x<=80 else -2)
    df['rsi_indication_diff']=df.rsi_indication.diff()

# %%
import numpy as np
def magnitude(v):
    return (v[0]**2+v[1]**2)**(1/2)

def compute_angle(arr):
    arr=arr.split(",")
    p0=(0,float(arr[0]))
    p1=(10,float(arr[1]))
    p2=(20,float(arr[2]))
    v1=[p0[0]-p1[0],p0[1]-p1[1]]
    v2=[p2[0]-p1[0],p2[1]-p1[1]]
    m1=magnitude(v1)
    m2=magnitude(v2)
    return 180-np.arccos(np.dot(v1,v2)/(magnitude(v1)*magnitude(v2)))*180/3.14

# %% [markdown]
# # About to change the direction using RSI

# %%
global historical_data, rsi, rsi_slope, last_close, swing,last_high,last_low,sma,ub,mb,lb,band_diff_trend,current_price
swing = False
name = "resources/EQUITY_L.csv"
symbols=list(pd.read_csv(name)['SYMBOL'])
trgt_type="resources/res_large_7_sma.csv"
count=0
for symbol in symbols:
    try:
        historical_data = get_data(symbol+".NS" , start_date = '01/01/2019')
        df = historical_data
        df = indicators.RSI(df,period=14)
        df=indicators.SMA(df, "close", "sma_7", 7)
        df=indicators.SMA(df, "close", "sma_50", 50)
        df['RSI_Trend'] = df['RSI_14'].diff()
        window = 20
        no_of_std = 2
        rolling_mean = df['close'].rolling(window).mean()
        rolling_std = df['close'].rolling(window).std()
        df['ub'] = rolling_mean + (rolling_std * no_of_std)
        df['mb'] = rolling_mean
        df['lb'] = rolling_mean - (rolling_std * no_of_std)
        df['ub_tren']= df['ub'].diff().round(0)
        df['lb_tren']= df['lb'].diff().round(0)
        df['3_ub_point']=df.ub.shift(2).apply(str)+","+    df.ub.shift(1).apply(str)+","+    df.ub.apply(str)
        df['3_lb_point']=df.lb.shift(2).apply(str)+","+    df.lb.shift(1).apply(str)+","+    df.lb.apply(str)
        df['divergence_angle']=df['3_ub_point'].apply(compute_angle)+df['3_lb_point'].apply(compute_angle)
        df['divergence_col']=df.apply(lambda x:  "divergence" if 25 <=x['divergence_angle']<=100 and x['ub_tren']>=0 and x['lb_tren']<=0 and x['ub_tren']!=x['lb_tren'] else '',axis=1)
        df['rsi_indication']=df.RSI_14.apply(lambda x:1 if x<=80 else -2)
        df['rsi_indication_diff']=df.rsi_indication.diff()
        count=count+1
        print(count)
        if(-3 in list(df[-7:].rsi_indication_diff)) :
            print("inside",symbol)
            df[-1:].to_csv(trgt_type,mode='a',index=False,header=False)
    except Exception as e:
        print("Error ",e)
        #print(traceback.format_exc())
        print("Not present symbol",symbol)

# %% [markdown]
# # Checking Support and ressistnace more than a week

# %%
global historical_data, rsi, rsi_slope, last_close, swing,last_high,last_low,sma,ub,mb,lb,band_diff_trend,current_price
swing = False
name = "resources/EQUITY_L.csv"
symbols=list(pd.read_csv(name)['SYMBOL'])
trgt_type="resources/res_large_7_sma.csv"
count=0
for symbol in symbols:
    try:
        historical_data = get_data(symbol+".NS" , start_date = '01/01/2019')
        df=historical_data
        reprocess_df(df)
        count=count+1
        print(count)
        closed_7thday=df[-7:-6].close
        closed_latest_day=df[-1:].close
        if(-3 in list(df[-7:].rsi_indication_diff)) :
            print("inside",symbol)
            df[-1:].to_csv(trgt_type,mode='a',index=False,header=False)
    except Exception as e:
        print("Error ",e)
        #print(traceback.format_exc())
        print("Not present symbol",symbol)

# %%
historical_data = get_data("INFY.NS" , start_date = '01/01/2019')
df=historical_data
reprocess_df(df)

# %%
# Out:
#              open   high         low  close  adjclose      volume   ticker  \
# 2020-04-30  700.0  720.0  698.099976  715.5     715.5  16253821.0  INFY.NS
#
#                RSI_14       sma_7   sma_50  ...          mb          lb  \
# 2020-04-30  61.968989  670.928563  675.021  ...  643.779996  587.826604
#
#             ub_tren  lb_tren  \
# 2020-04-30     14.0     -8.0
#
#                                                    3_ub_point  \
# 2020-04-30  680.6873921418846,685.6191274706752,699.733387...
#
#                                                    3_lb_point  \
# 2020-04-30  597.2376017545998,595.660865205106,587.8266037...
#
#            divergence_angle divergence_col  rsi_indication rsi_indication_diff
# 2020-04-30        57.393408     divergence               1                 0.0
#
# [1 rows x 22 columns]

# %%
# Out:
#                   open        high         low       close    adjclose  \
# 2019-01-01  660.950012  666.299988  654.150024  665.049988  640.886658
# 2019-01-02  666.000000  674.000000  662.049988  669.049988  644.741272
# 2019-01-03  672.000000  677.000000  663.099976  669.150024  644.837646
# 2019-01-04  671.750000  673.900024  651.000000  661.049988  637.031982
# 2019-01-07  665.000000  673.599976  661.500000  671.700012  647.295044
# 2019-01-08  674.950012  677.450012  668.549988  670.049988  645.704956
# 2019-01-09  686.200012  689.799988  664.000000  676.099976  651.535095
# 2019-01-10  681.599976  682.000000  672.549988  679.700012  655.004333
# 2019-01-11  680.200012  685.500000  672.500000  683.500000  658.666260
# 2019-01-14  707.000000  710.200012  695.950012  701.900024  676.397766
# 2019-01-15  707.200012  730.000000  707.200012  726.599976  700.200256
# 2019-01-16  729.900024  737.799988  728.500000  736.799988  710.029663
# 2019-01-17  735.799988  739.000000  729.099976  733.349976  706.705078
# 2019-01-18  730.000000  736.200012  726.299988  730.950012  704.392334
# 2019-01-21  738.200012  751.000000  734.000000  745.000000  717.931763
# 2019-01-22  741.250000  749.000000  734.000000  745.349976  718.269043
# 2019-01-23  742.349976  742.599976  729.200012  731.650024  705.066833
# 2019-01-24  728.099976  736.099976  721.000000  732.000000  705.404114
# 2019-01-25  728.000000  737.900024  724.250000  730.349976  703.814026
# 2019-01-28  731.000000  732.599976  719.000000  727.950012  701.501282
# 2019-01-29  725.500000  732.849976  716.500000  727.900024  701.453064
# 2019-01-30  727.900024  734.799988  721.099976  725.900024  699.525757
# 2019-01-31  726.000000  751.299988  726.000000  749.549988  722.316467
# 2019-02-01  751.349976  762.500000  744.500000  757.049988  729.543945
# 2019-02-04  757.000000  762.500000  749.200012  755.900024  728.435791
# 2019-02-05  747.000000  759.950012  747.000000  754.849976  727.423889
# 2019-02-06  755.549988  766.950012  754.349976  763.299988  735.566895
# 2019-02-07  763.049988  769.450012  761.000000  764.000000  736.241455
# 2019-02-08  760.000000  772.250000  754.900024  760.900024  733.254089
# 2019-02-11  766.900024  768.750000  759.000000  762.799988  735.085022
# ...                ...         ...         ...         ...         ...
# 2020-03-16  622.000000  622.150024  580.000000  583.150024  583.150024
# 2020-03-17  588.099976  592.000000  550.000000  554.950012  554.950012
# 2020-03-18  568.000000  578.000000  528.000000  534.299988  534.299988
# 2020-03-19  509.250000  558.000000  509.250000  545.549988  545.549988
# 2020-03-20  549.500000  617.450012  548.000000  585.200012  585.200012
# 2020-03-23  540.000000  560.950012  515.900024  526.450012  526.450012
# 2020-03-24  522.000000  601.150024  522.000000  589.799988  589.799988
# 2020-03-25  597.000000  635.000000  565.700012  606.200012  606.200012
# 2020-03-26  615.000000  650.849976  612.099976  643.000000  643.000000
# 2020-03-27  665.049988  674.900024  642.250000  652.700012  652.700012
# 2020-03-30  625.099976  663.500000  621.099976  626.700012  626.700012
# 2020-03-31  650.000000  662.000000  633.700012  641.500000  641.500000
# 2020-04-01  634.349976  637.500000  594.000000  602.799988  602.799988
# 2020-04-03  603.500000  606.000000  582.150024  585.700012  585.700012
# 2020-04-07  615.000000  644.250000  612.900024  639.000000  639.000000
# 2020-04-08  630.000000  655.650024  626.349976  631.599976  631.599976
# 2020-04-09  646.799988  652.799988  632.099976  636.250000  636.250000
# 2020-04-13  629.000000  651.700012  626.049988  637.400024  637.400024
# 2020-04-15  651.400024  653.299988  635.599976  639.049988  639.049988
# 2020-04-16  619.950012  634.900024  603.500000  623.849976  623.849976
# 2020-04-17  644.000000  646.000000  626.000000  628.750000  628.750000
# 2020-04-20  640.000000  661.000000  639.000000  653.299988  653.299988
# 2020-04-21  627.799988  646.500000  627.799988  633.200012  633.200012
# 2020-04-22  633.200012  645.000000  628.049988  641.849976  641.849976
# 2020-04-23  647.049988  683.650024  638.099976  679.299988  679.299988
# 2020-04-24  668.549988  675.000000  654.799988  658.000000  658.000000
# 2020-04-27  661.049988  681.000000  661.049988  664.599976  664.599976
# 2020-04-28  673.000000  677.000000  653.049988  660.700012  660.700012
# 2020-04-29  666.000000  682.000000  658.000000  676.549988  676.549988
# 2020-04-30  700.000000  720.000000  698.099976  715.500000  715.500000
#
#                 volume   ticker      RSI_14       sma_7      sma_50  ...  \
# 2019-01-01   2943390.0  INFY.NS    0.000000    0.000000    0.000000  ...
# 2019-01-02   7416655.0  INFY.NS  100.000000    0.000000    0.000000  ...
# 2019-01-03   6827249.0  INFY.NS  100.000000    0.000000    0.000000  ...
# 2019-01-04   7889310.0  INFY.NS   85.658231    0.000000    0.000000  ...
# 2019-01-07   8046340.0  INFY.NS   88.079048    0.000000    0.000000  ...
# 2019-01-08   8621545.0  INFY.NS   85.666398    0.000000    0.000000  ...
# 2019-01-09  18130292.0  INFY.NS   87.065415  668.878566    0.000000  ...
# 2019-01-10   9572493.0  INFY.NS   87.826809  670.971427    0.000000  ...
# 2019-01-11  12281903.0  INFY.NS   88.590278  673.035714    0.000000  ...
# 2019-01-14  19312937.0  INFY.NS   91.402162  677.714286    0.000000  ...
# 2019-01-15  19671304.0  INFY.NS   93.660694  687.078570    0.000000  ...
# 2019-01-16   9658944.0  INFY.NS   94.323802  696.378566    0.000000  ...
# 2019-01-17   6903771.0  INFY.NS   90.861793  705.421422    0.000000  ...
# 2019-01-18   5902151.0  INFY.NS   88.430280  713.257141    0.000000  ...
# 2019-01-21   8129422.0  INFY.NS   90.100470  722.585711    0.000000  ...
# 2019-01-22   6723375.0  INFY.NS   90.138658  731.421422    0.000000  ...
# 2019-01-23   7212099.0  INFY.NS   77.530555  735.671422    0.000000  ...
# 2019-01-24   7429783.0  INFY.NS   77.616687  736.442854    0.000000  ...
# 2019-01-25   5543112.0  INFY.NS   76.134869  735.521423    0.000000  ...
# 2019-01-28   7944693.0  INFY.NS   73.924191  734.750000    0.000000  ...
# 2019-01-29   6760819.0  INFY.NS   73.876075  734.314287    0.000000  ...
# 2019-01-30   5763026.0  INFY.NS   71.860748  731.585720    0.000000  ...
# 2019-01-31  13825233.0  INFY.NS   79.115852  732.185721    0.000000  ...
# 2019-02-01   6276585.0  INFY.NS   80.805954  735.814287    0.000000  ...
# 2019-02-04   3945391.0  INFY.NS   79.740384  739.228577    0.000000  ...
# 2019-02-05   4694366.0  INFY.NS   78.719605  742.728577    0.000000  ...
# 2019-02-06   5880482.0  INFY.NS   80.844685  747.778573    0.000000  ...
# 2019-02-07   3961797.0  INFY.NS   81.013833  752.935713    0.000000  ...
# 2019-02-08   5915169.0  INFY.NS   77.739986  757.935713    0.000000  ...
# 2019-02-11   5500216.0  INFY.NS   78.318300  759.828570    0.000000  ...
# ...                ...      ...         ...         ...         ...  ...
# 2020-03-16  19140152.0  INFY.NS   18.126538  677.242859  757.450000  ...
# 2020-03-17  16059887.0  INFY.NS   16.147177  648.721436  753.629000  ...
# 2020-03-18  15390183.0  INFY.NS   14.866947  619.485718  749.538000  ...
# 2020-03-19  16583991.0  INFY.NS   18.651025  596.785714  745.891000  ...
# 2020-03-20  21354894.0  INFY.NS   30.394140  582.385716  743.231000  ...
# 2020-03-23  17146150.0  INFY.NS   24.703738  567.421430  739.209000  ...
# 2020-03-24  20027097.0  INFY.NS   38.150369  559.914289  736.242000  ...
# 2020-03-25  18339548.0  INFY.NS   41.083682  563.207145  732.895000  ...
# 2020-03-26  14843813.0  INFY.NS   47.141597  575.785714  730.242000  ...
# 2020-03-27  13495283.0  INFY.NS   48.640648  592.700003  727.945000  ...
# 2020-03-30  14624804.0  INFY.NS   44.960077  604.292864  725.139000  ...
# 2020-03-31  15175521.0  INFY.NS   47.399990  612.335720  722.612001  ...
# 2020-04-01  13083824.0  INFY.NS   42.139564  623.242859  719.299000  ...
# 2020-04-03  10221655.0  INFY.NS   40.025821  622.657148  715.763000  ...
# 2020-04-07  15145605.0  INFY.NS   48.668737  627.342861  713.139000  ...
# 2020-04-08  11806896.0  INFY.NS   47.642191  625.714286  710.084000  ...
# 2020-04-09  11931114.0  INFY.NS   48.379011  623.364284  707.154000  ...
# 2020-04-13   8330276.0  INFY.NS   48.571771  624.892857  704.340001  ...
# 2020-04-15  11963447.0  INFY.NS   48.866788  624.542855  701.561001  ...
# 2020-04-16  17783287.0  INFY.NS   46.235462  627.549997  698.244000  ...
# 2020-04-17   8878320.0  INFY.NS   47.222087  633.699995  695.205000  ...
# 2020-04-20  13322913.0  INFY.NS   51.977006  635.742850  692.752000  ...
# 2020-04-21  11660575.0  INFY.NS   48.151983  635.971427  690.067999  ...
# 2020-04-22   8266728.0  INFY.NS   49.861973  636.771423  687.147999  ...
# 2020-04-23  14451289.0  INFY.NS   56.544335  642.757132  685.042999  ...
# 2020-04-24   7319940.0  INFY.NS   52.276739  645.464277  682.776000  ...
# 2020-04-27   7183306.0  INFY.NS   53.449123  651.285706  680.522000  ...
# 2020-04-28   7296571.0  INFY.NS   52.626413  655.849993  678.272000  ...
# 2020-04-29   8639056.0  INFY.NS   55.616476  659.171422  676.332000  ...
# 2020-04-30  16253821.0  INFY.NS   61.968989  670.928563  675.021000  ...
#
#                     mb          lb  ub_tren  lb_tren  \
# 2019-01-01         NaN         NaN      NaN      NaN
# 2019-01-02         NaN         NaN      NaN      NaN
# 2019-01-03         NaN         NaN      NaN      NaN
# 2019-01-04         NaN         NaN      NaN      NaN
# 2019-01-07         NaN         NaN      NaN      NaN
# 2019-01-08         NaN         NaN      NaN      NaN
# 2019-01-09         NaN         NaN      NaN      NaN
# 2019-01-10         NaN         NaN      NaN      NaN
# 2019-01-11         NaN         NaN      NaN      NaN
# 2019-01-14         NaN         NaN      NaN      NaN
# 2019-01-15         NaN         NaN      NaN      NaN
# 2019-01-16         NaN         NaN      NaN      NaN
# 2019-01-17         NaN         NaN      NaN      NaN
# 2019-01-18         NaN         NaN      NaN      NaN
# 2019-01-21         NaN         NaN      NaN      NaN
# 2019-01-22         NaN         NaN      NaN      NaN
# 2019-01-23         NaN         NaN      NaN      NaN
# 2019-01-24         NaN         NaN      NaN      NaN
# 2019-01-25         NaN         NaN      NaN      NaN
# 2019-01-28  704.362497  640.840852      NaN      NaN
# 2019-01-29  707.504999  645.985156      1.0      5.0
# 2019-01-30  710.347501  651.097317      1.0      5.0
# 2019-01-31  714.367499  655.982802      3.0      5.0
# 2019-02-01  719.167499  663.518394      2.0      8.0
# 2019-02-04  723.377499  670.161865      2.0      7.0
# 2019-02-05  727.617499  678.975555     -0.0      9.0
# 2019-02-06  731.977499  687.308714      0.0      8.0
# 2019-02-07  736.192499  696.682721     -1.0      9.0
# 2019-02-08  740.062500  707.783188     -3.0     11.0
# 2019-02-11  743.107498  714.732342     -1.0      7.0
# ...                ...         ...      ...      ...
# 2020-03-16  742.252502  616.297101     13.0    -33.0
# 2020-03-17  730.677502  581.428988     12.0    -35.0
# 2020-03-18  717.920001  547.680752      8.0    -34.0
# 2020-03-19  705.314999  523.026343     -1.0    -25.0
# 2020-03-20  694.552499  510.505141     -9.0    -13.0
# 2020-03-23  681.025000  489.080992     -6.0    -21.0
# 2020-03-24  670.722501  482.648449    -14.0     -6.0
# 2020-03-25  661.112500  481.036001    -18.0     -2.0
# 2020-03-26  654.125000  483.314721    -16.0      2.0
# 2020-03-27  647.867502  487.277959    -16.0      4.0
# 2020-03-30  642.617502  486.772317    -10.0     -1.0
# 2020-03-31  637.640002  488.831781    -12.0      2.0
# 2020-04-01  630.430002  490.206122    -16.0      1.0
# 2020-04-03  621.777502  494.097447    -21.0      4.0
# 2020-04-07  615.997504  504.149797    -22.0     10.0
# 2020-04-08  610.630002  514.415344    -21.0     10.0
# 2020-04-09  607.220001  520.655617    -13.0      6.0
# 2020-04-13  604.790002  525.079919     -9.0      4.0
# 2020-04-15  605.182501  524.849983      1.0     -0.0
# 2020-04-16  604.257501  525.312910     -2.0      0.0
# 2020-04-17  606.537500  527.525750      2.0      2.0
# 2020-04-20  611.454999  533.730256      4.0      6.0
# 2020-04-21  616.400000  547.230059     -4.0     13.0
# 2020-04-22  621.214999  559.843694     -3.0     13.0
# 2020-04-23  625.919998  561.807231      7.0      2.0
# 2020-04-24  632.497498  587.088940    -12.0     25.0
# 2020-04-27  636.237497  593.386615      1.0      6.0
# 2020-04-28  638.962497  597.237602      2.0      4.0
# 2020-04-29  640.639996  595.660865      5.0     -2.0
# 2020-04-30  643.779996  587.826604     14.0     -8.0
#
#                                                    3_ub_point  \
# 2019-01-01                                        nan,nan,nan
# 2019-01-02                                        nan,nan,nan
# 2019-01-03                                        nan,nan,nan
# 2019-01-04                                        nan,nan,nan
# 2019-01-07                                        nan,nan,nan
# 2019-01-08                                        nan,nan,nan
# 2019-01-09                                        nan,nan,nan
# 2019-01-10                                        nan,nan,nan
# 2019-01-11                                        nan,nan,nan
# 2019-01-14                                        nan,nan,nan
# 2019-01-15                                        nan,nan,nan
# 2019-01-16                                        nan,nan,nan
# 2019-01-17                                        nan,nan,nan
# 2019-01-18                                        nan,nan,nan
# 2019-01-21                                        nan,nan,nan
# 2019-01-22                                        nan,nan,nan
# 2019-01-23                                        nan,nan,nan
# 2019-01-24                                        nan,nan,nan
# 2019-01-25                                        nan,nan,nan
# 2019-01-28                          nan,nan,767.8841422054608
# 2019-01-29            nan,767.8841422054608,769.0248418679181
# 2019-01-30  767.8841422054608,769.0248418679181,769.597684...
# 2019-01-31  769.0248418679181,769.597684638109,772.7521952...
# 2019-02-01  769.597684638109,772.752195243133,774.81660356...
# 2019-02-04  772.752195243133,774.8166035646491,776.5931335...
# 2019-02-05  774.8166035646491,776.5931335317431,776.259443...
# 2019-02-06  776.5931335317431,776.2594430461593,776.646284...
# 2019-02-07  776.2594430461593,776.646284545268,775.7022769...
# 2019-02-08  776.646284545268,775.7022769872326,772.3418120...
# 2019-02-11  775.7022769872326,772.3418120422119,771.482653...
# ...                                                       ...
# 2020-03-16  849.1090664196753,855.6716093668427,868.207903...
# 2020-03-17  855.6716093668427,868.2079036393068,879.926016...
# 2020-03-18  868.2079036393068,879.9260166086768,888.159250...
# 2020-03-19  879.9260166086768,888.1592500614404,887.603655...
# 2020-03-20  888.1592500614404,887.6036555457997,878.599858...
# 2020-03-23  887.6036555457997,878.5998580732169,872.969007...
# 2020-03-24  878.5998580732169,872.9690075445943,858.796552...
# 2020-03-25  872.9690075445943,858.796552439168,841.1889994...
# 2020-03-26  858.796552439168,841.1889994189706,824.9352794...
# 2020-03-27  841.1889994189706,824.9352794448953,808.457044...
# 2020-03-30  824.9352794448953,808.4570441719574,798.462686...
# 2020-03-31  808.4570441719574,798.4626868807212,786.448224...
# 2020-04-01  798.4626868807212,786.4482242036914,770.653881...
# 2020-04-03  786.4482242036914,770.6538814573726,749.457557...
# 2020-04-07  770.6538814573726,749.4575574397837,727.845210...
# 2020-04-08  749.4575574397837,727.8452106879897,706.844659...
# 2020-04-09  727.8452106879897,706.8446595364786,693.784385...
# 2020-04-13  706.8446595364786,693.7843850155873,684.500085...
# 2020-04-15  693.7843850155873,684.5000853860258,685.515019...
# 2020-04-16  684.5000853860258,685.5150195876233,683.202092...
# 2020-04-17  685.5150195876233,683.2020921924411,685.549250...
# 2020-04-20  683.2020921924411,685.5492501430747,689.179742...
# 2020-04-21  685.5492501430747,689.1797420063114,685.569941...
# 2020-04-22  689.1797420063114,685.5699414003648,682.586304...
# 2020-04-23  685.5699414003648,682.5863048969909,690.032765...
# 2020-04-24  682.5863048969909,690.0327651367036,677.906054...
# 2020-04-27  690.0327651367036,677.906054983136,679.0883791...
# 2020-04-28  677.906054983136,679.0883791762521,680.6873921...
# 2020-04-29  679.0883791762521,680.6873921418846,685.619127...
# 2020-04-30  680.6873921418846,685.6191274706752,699.733387...
#
#                                                    3_lb_point  \
# 2019-01-01                                        nan,nan,nan
# 2019-01-02                                        nan,nan,nan
# 2019-01-03                                        nan,nan,nan
# 2019-01-04                                        nan,nan,nan
# 2019-01-07                                        nan,nan,nan
# 2019-01-08                                        nan,nan,nan
# 2019-01-09                                        nan,nan,nan
# 2019-01-10                                        nan,nan,nan
# 2019-01-11                                        nan,nan,nan
# 2019-01-14                                        nan,nan,nan
# 2019-01-15                                        nan,nan,nan
# 2019-01-16                                        nan,nan,nan
# 2019-01-17                                        nan,nan,nan
# 2019-01-18                                        nan,nan,nan
# 2019-01-21                                        nan,nan,nan
# 2019-01-22                                        nan,nan,nan
# 2019-01-23                                        nan,nan,nan
# 2019-01-24                                        nan,nan,nan
# 2019-01-25                                        nan,nan,nan
# 2019-01-28                          nan,nan,640.8408516910237
# 2019-01-29            nan,640.8408516910237,645.9851556906757
# 2019-01-30  640.8408516910237,645.9851556906757,651.097316...
# 2019-01-31  645.9851556906757,651.0973165825941,655.982802...
# 2019-02-01  651.0973165825941,655.9828023154607,663.518393...
# 2019-02-04  655.9828023154607,663.5183939939448,670.161865...
# 2019-02-05  663.5183939939448,670.1618652475537,678.975554...
# 2019-02-06  670.1618652475537,678.9755545124344,687.308714...
# 2019-02-07  678.9755545124344,687.3087142340288,696.682720...
# 2019-02-08  687.3087142340288,696.6827205713612,707.783187...
# 2019-02-11  696.6827205713612,707.7831879577881,714.732342...
# ...                                                       ...
# 2020-03-16  670.1759372424341,649.7433930745634,616.297101...
# 2020-03-17  649.7433930745634,616.2971012435057,581.428988...
# 2020-03-18  616.2971012435057,581.4289882741356,547.680752...
# 2020-03-19  581.4289882741356,547.680752379966,523.0263432...
# 2020-03-20  547.680752379966,523.0263432334971,510.5051407...
# 2020-03-23  523.0263432334971,510.50514070608006,489.08099...
# 2020-03-24  510.50514070608006,489.08099245540564,482.6484...
# 2020-03-25  489.08099245540564,482.6484487815351,481.03600...
# 2020-03-26  482.6484487815351,481.03600058102927,483.31472...
# 2020-03-27  481.03600058102927,483.3147205551047,487.27795...
# 2020-03-30  483.3147205551047,487.27795949015206,486.77231...
# 2020-03-31  487.27795949015206,486.7723167813882,488.83178...
# 2020-04-01  486.7723167813882,488.83178067912115,490.20612...
# 2020-04-03  488.83178067912115,490.20612220473686,494.0974...
# 2020-04-07  490.20612220473686,494.09744744302867,504.1497...
# 2020-04-08  494.09744744302867,504.1497966362289,514.41534...
# 2020-04-09  504.1497966362289,514.4153441256307,520.655617...
# 2020-04-13  514.4153441256307,520.655617425819,525.0799194...
# 2020-04-15  520.655617425819,525.0799194967867,524.8499828...
# 2020-04-16  525.0799194967867,524.8499828537829,525.312910...
# 2020-04-17  524.8499828537829,525.3129102489652,527.525749...
# 2020-04-20  525.3129102489652,527.5257498569254,533.730255...
# 2020-04-21  527.5257498569254,533.7302555522823,547.230058...
# 2020-04-22  533.7302555522823,547.2300585996352,559.843693...
# 2020-04-23  547.2300585996352,559.8436938823061,561.807231...
# 2020-04-24  559.8436938823061,561.807231201187,587.0889401...
# 2020-04-27  561.807231201187,587.0889401340515,593.3866147...
# 2020-04-28  587.0889401340515,593.3866147202323,597.237601...
# 2020-04-29  593.3866147202323,597.2376017545998,595.660865...
# 2020-04-30  597.2376017545998,595.660865205106,587.8266037...
#
#            divergence_angle divergence_col  rsi_indication rsi_indication_diff
# 2019-01-01              NaN                              1                 NaN
# 2019-01-02              NaN                             -2                -3.0
# 2019-01-03              NaN                             -2                 0.0
# 2019-01-04              NaN                             -2                 0.0
# 2019-01-07              NaN                             -2                 0.0
# 2019-01-08              NaN                             -2                 0.0
# 2019-01-09              NaN                             -2                 0.0
# 2019-01-10              NaN                             -2                 0.0
# 2019-01-11              NaN                             -2                 0.0
# 2019-01-14              NaN                             -2                 0.0
# 2019-01-15              NaN                             -2                 0.0
# 2019-01-16              NaN                             -2                 0.0
# 2019-01-17              NaN                             -2                 0.0
# 2019-01-18              NaN                             -2                 0.0
# 2019-01-21              NaN                             -2                 0.0
# 2019-01-22              NaN                             -2                 0.0
# 2019-01-23              NaN                              1                 3.0
# 2019-01-24              NaN                              1                 0.0
# 2019-01-25              NaN                              1                 0.0
# 2019-01-28              NaN                              1                 0.0
# 2019-01-29              NaN                              1                 0.0
# 2019-01-30         3.193968                              1                 0.0
# 2019-01-31        15.093611                              1                 0.0
# 2019-02-01        16.631965                             -2                -3.0
# 2019-02-04         4.812821                              1                 3.0
# 2019-02-05        19.606288                              1                 0.0
# 2019-02-06         5.533797                             -2                -3.0
# 2019-02-07        10.775451                             -2                 0.0
# 2019-02-08        17.844623                              1                 3.0
# 2019-02-11        26.684659                              1                 0.0
# ...                     ...            ...             ...                 ...
# 2020-03-16        27.409393     divergence               1                 0.0
# 2020-03-17         2.360006                              1                 0.0
# 2020-03-18        10.383117                              1                 0.0
# 2020-03-19        48.059976                              1                 0.0
# 2020-03-20        55.199290                              1                 0.0
# 2020-03-23        26.037739                              1                 0.0
# 2020-03-24        57.484106                              1                 0.0
# 2020-03-25        29.036410                              1                 0.0
# 2020-03-26        23.834051                              1                 0.0
# 2020-03-27         8.954444                              1                 0.0
# 2020-03-30        38.115313                              1                 0.0
# 2020-03-31        19.603777                              1                 0.0
# 2020-04-01        11.067061                              1                 0.0
# 2020-04-03        20.347528                              1                 0.0
# 2020-04-07        24.143771                              1                 0.0
# 2020-04-08         1.052030                              1                 0.0
# 2020-04-09        25.593728                              1                 0.0
# 2020-04-13        17.610534                              1                 0.0
# 2020-04-15        73.707967     divergence               1                 0.0
# 2020-04-16        22.615046                              1                 0.0
# 2020-04-17        35.894986                              1                 0.0
# 2020-04-20        25.914889                              1                 0.0
# 2020-04-21        61.303721                              1                 0.0
# 2020-04-22         4.933252                              1                 0.0
# 2020-04-23        93.635180                              1                 0.0
# 2020-04-24       144.364037                              1                 0.0
# 2020-04-27        93.315530                              1                 0.0
# 2020-04-28        13.305846                              1                 0.0
# 2020-04-29        47.029768     divergence               1                 0.0
# 2020-04-30        57.393408     divergence               1                 0.0
#
# [324 rows x 22 columns]

# %% [raw]
# global historical_data, rsi, rsi_slope, last_close, swing,last_high,last_low,sma,ub,mb,lb,band_diff_trend,current_price
# swing = False
# name = "resources/EQUITY_L.csv"
# symbols=list(pd.read_csv(name)['SYMBOL'])
# trgt_type="resources/res_large_7_sma.csv"
# count=0
# for symbol in symbols:
#     try:
#         historical_data = get_data(symbol+".NS" , start_date = '01/01/2019')
#         df = historical_data
#         df = indicators.RSI(df,period=14)
#         df=indicators.SMA(df, "close", "sma_7", 7)
#         df=indicators.SMA(df, "close", "sma_50", 50)
#         df['RSI_Trend'] = df['RSI_14'].diff()
#         window = 20
#         no_of_std = 2
#         rolling_mean = df['close'].rolling(window).mean()
#         rolling_std = df['close'].rolling(window).std()
#         df['ub'] = rolling_mean + (rolling_std * no_of_std)
#         df['mb'] = rolling_mean
#         df['lb'] = rolling_mean - (rolling_std * no_of_std)
#         df['ub_tren']= df['ub'].diff().round(0)
#         df['lb_tren']= df['lb'].diff().round(0)
#         df['3_ub_point']=df.ub.shift(2).apply(str)+","+    df.ub.shift(1).apply(str)+","+    df.ub.apply(str)
#         df['3_lb_point']=df.lb.shift(2).apply(str)+","+    df.lb.shift(1).apply(str)+","+    df.lb.apply(str)
#         df['divergence_angle']=df['3_ub_point'].apply(compute_angle)+df['3_lb_point'].apply(compute_angle)
#         df['divergence_col']=df.apply(lambda x:  "divergence" if 25 <=x['divergence_angle']<=100 and x['ub_tren']>=0 and x['lb_tren']<=0 and x['ub_tren']!=x['lb_tren'] else '',axis=1)
#         df['rsi_indication']=df.RSI_14.apply(lambda x:1 if x<=20 else -2)
#         df['rsi_indication_diff']=df.rsi_indication.diff()
#         count=count+1
#         print(count)
#         if(-3 in list(df[-7:].rsi_indication_diff)) :
#             print("inside",symbol)
#             df[-1:].to_csv(trgt_type,mode='a',index=False,header=False)
#     except Exception as e:
#         print("Error ",e)
#         print(traceback.format_exc())
#         print("Not present symbol",symbol)

# %%
global historical_data, rsi, rsi_slope, last_close, swing,last_high,last_low,sma,ub,mb,lb,band_diff_trend,current_price
swing = False
name = "resources/EQUITY_L.csv"
symbols=list(pd.read_csv(name)['SYMBOL'])[0:1]
trgt_type="resources/res_1.csv"
count=0
symbol='CINELINE'
historical_data = get_data(symbol+".NS" , start_date = '01/01/2019')
df = historical_data
df = indicators.RSI(df,period=14)
df=indicators.SMA(df, "close", "sma_7", 7)
df['RSI_Trend'] = df['RSI_14'].diff()
window = 20
no_of_std = 2
rolling_mean = df['close'].rolling(window).mean()
rolling_std = df['close'].rolling(window).std()
df['ub'] = rolling_mean + (rolling_std * no_of_std)
df['mb'] = rolling_mean
df['lb'] = rolling_mean - (rolling_std * no_of_std)
df['ub_tren']= df['ub'].diff().round(0)
df['lb_tren']= df['lb'].diff().round(0)
df['3_ub_point']=df.ub.shift(2).apply(str)+","+    df.ub.shift(1).apply(str)+","+    df.ub.apply(str)
df['3_lb_point']=df.lb.shift(2).apply(str)+","+    df.lb.shift(1).apply(str)+","+    df.lb.apply(str)
df['divergence_angle']=df['3_ub_point'].apply(compute_angle)+df['3_lb_point'].apply(compute_angle)
df['divergence_col']=df.apply(lambda x:  "divergence" if 25 <=x['divergence_angle']<=100 and x['ub_tren']>=0 and x['lb_tren']<=0 and x['ub_tren']!=x['lb_tren'] else '',axis=1)
df['rsi_indication']=df.RSI_14.apply(lambda x:1 if x<=30 else -2)
df['rsi_indication_diff']=df.rsi_indication.diff()
count=count+1
print(count)
if(-3 in list(df[-:].rsi_indication_diff)) 
    print("inside",symbol)
    df[-1:].to_csv(trgt_type,mode='a',index=False,header=False)

# %%
df[-7:]

# %%
get_analysts_info('nflx')

# %%
try:
    raise("dfhjksdfl")
except Exception as e:
    print(str(e))

# %%
global historical_data, rsi, rsi_slope, last_close, swing,last_high,last_low,sma,ub,mb,lb,band_diff_trend,current_price
swing = False
name = "resources/EQUITY_L.csv"
symbols=list(pd.read_csv(name)['SYMBOL'])
trgt_type="resources/res_large_7_sma.csv"
count=0
for symbol in symbols:
    try:
        last_price = get_price(symbol, 0.00)
        if(5<=last_price<=10):
            print(symbol)
    except:
        pass
# Out:
# 3PLAND
# AARVEEDEN
# ADROITINFO
# AKSHOPTFBR
# ALOKINDS
# ANIKINDS
# ANSALAPI
# ARENTERP
# ATLANTA
# BAJAJHIND
# BCG
# BEARDSELL
# BINANIIND
# BINDALAGRO
# BIRLATYRE
# BYKE
# CALSOFT
# CEBBCO
# CELEBRITY
# CGPOWER
# CINEVISTA
# CNOVAPETRO
# COMPUSOFT
# DBSTOCKBRO
# DHARSUGAR
# DPSCLTD
# EON
# ESSARSHPNG
# EUROTEXIND
# FCONSUMER
# FLEXITUFF
# GARDENSILK
# GBGLOBAL
# GINNIFILA
# GOLDTECH
# GTNIND
# GTNTEX
# GUJRAFFIA
# HBSL
# HCL-INSYS
# HEXATRADEX
# HILTON
# INDBANK
# IOB
# JBFIND
# JISLDVREQS
# JISLJALEQS
# JIYAECO
# JPOLYINVST
# KARMAENG
# KECL
# KMSUGAR
# KOHINOOR
# KOTARISUG
# MAHABANK
# MANAKSTEEL
# MANGTIMBER
# MANPASAND
# MANUGRAPH
# MEGASOFT
# MIRCELECTR
# MOHOTAIND
# MORARJEE
# MTNL
# MUKANDENGG
# NAGREEKCAP
# NAGREEKEXP
# NECCLTD
# NIBL
# get_price exception  0
# get_price exception  1
# get_price exception  2
# get_price exception  3
# returning old price  0.0
# NKIND
# ONELIFECAP
# ORIENTALTL
# OSWALAGRO
# PARACABLES
# PFS
# RELCAPITAL
# RENUKA
# RKDL
# SAKHTISUG
# SAKUMA
# SANCO
# SGL
# SHAHALLOYS
# SHIRPUR-G
# SHYAMTEL
# SICAL
# SIL
# SIMBHALS
# SOUTHBANK
# SPMLINFRA
# SUBCAPCITY
# SUPREMEINF
# SURANASOL
# TCIFINANCE
# TECHNOFAB
# THOMASCOTT
# TIJARIA
# TREJHARA
# TRIL
# UNIPLY
# UTTAMSTL
# VASCONEQ
# VIKASWSP
# VIPCLOTHNG
# ZEEMEDIA

# %%
from pyspark.sql import functions as f
from pyspark.sql.functions import *
from pyspark import StorageLevel
from datetime import timedelta
import datetime
import csv
import os.path
from datetime import datetime as d
import re
import subprocess as sp

back_date = 4
today = datetime.datetime.now().date()
start_date = today - timedelta(days=(today.weekday()-3)%7+7)

# %%
str(start_date)
# Out:
# '2020-04-23'

# %%
data=spark.read.csv(path,spep='\t',header=True)
d_temp=data.withColumn("Date",lit(start_date))
d_temp.write.csv("temp")
rm -r path
mv temp path
