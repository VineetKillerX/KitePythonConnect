# %%
import sys
import requests 
from bs4 import BeautifulSoup 
import os
import pandas as pd
import shutil
import re
# keyId = "AKIAJQN63IU3OQEOVZGA"
# sKeyId="/8kumPC95exeYVS56Ly/cw6vay3bttFwLwLTtTkc" 
# bucket_name=application_properties.properties['bucket']
# conn = boto.connect_s3(keyId,sKeyId)
# bucket = conn.get_bucket(bucket_name, validate=True)

# %%
def get_links(archive_url,trgt_type,kernel):
    r = requests.get(archive_url)
    soup = BeautifulSoup(r.content,'html.parser')
    os.path
    
    list1 =soup.get_text().split('\n')
    r = re.compile(r".*\d{4}-\d{2}-\d{2}.*")
    newlist_match =[]
    print(archive_url)
    for names in list1:
        if bool(re.search(r".*\d{4}-\d{2}-\d{2}.*", names) and '.txt ' in names):
            names=names.strip()
            newlist_match.append([kernel,names.split("txt")[0].strip()+"txt",names.split("txt")[1].strip().split(" ")[0]])
            #newlist_match.append(names)
            df=pd.DataFrame(newlist_match,columns=["kernel","File Name",'Last Modified Date'])
    df.to_csv(trgt_type,mode='a',index=False)
#     with pd.ExcelWriter('./report.xlsx',mode='a') as writer:  
#         df.to_excel(writer, sheet_name=trgt_type)

# %%
args=["SAP-PIL", "SAP-MBP", "cPLM BH_HS_Ultrasound", "SAP-GTS", "SAP-MCP", "SAP-MP1"]
# for i in range(1,args,1):    
# kernel=sys.argv[i]
# print(kernel)
kernel=args[0]
file_types=["lookups","value_maps","scope"]

# %%
type=file_types[2]

# %%
if type=="lookups":
    trgt_type="ValueSets"
elif type=="value_maps":
    trgt_type="ValueMaps"
elif type=="scope":
    trgt_type="Scope"
type
# Out:
# 'scope'

# %%
if kernel=="SAP-PIL" and type=="lookups":
    sub_ker=["PIL"]
    for ker in sub_ker:
        archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
        #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
        
            
        
        file_links = get_links(archive_url,trgt_type,ker)
        #download_series(file_links)
        #updt_kernel=kernel+"/"+ker
        #upload_files(trgt_type,updt_kernel)
        
elif kernel=="BH_HS_Ultrasound" and type=="lookups":
    sub_ker=["PR1","MBP",""]
    for ker in sub_ker:
        archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
        #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
        
            
        
        file_links = get_links(archive_url,trgt_type,ker)
        #download_series(file_links)
        #updt_kernel=kernel+"/"+ker
        #upload_files(trgt_type,updt_kernel)
    
elif kernel=="SAP-PIL" and type=="value_maps":
    sub_ker=["PIL","CEP","MP1","WPA","WPX"]
    for ker in sub_ker:
        archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
        #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
        

        file_links = get_links(archive_url,trgt_type,ker)
        #download_series(file_links)
        #updt_kernel=kernel+"/"+ker
        #upload_files(trgt_type,updt_kernel)
    
    
else:
    archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/" + type +  "/" 
    #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel
    file_links = get_links(archive_url,trgt_type,kernel)
    #download_series(file_links)
    #upload_files(trgt_type,kernel)
    

if kernel == 'SAP-MBP' and type == 'scope':
    #check for BH_HS_Hamburg
    internal_kernel = "BH_HS_Hamburg"
    archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/" + internal_kernel  +  "/" + type+"/"
    #path_dir="/root/DQIP/dqip_data/"+trgt_type+internal_kernel
    file_links = get_links(archive_url,trgt_type,kernel)
    #download_series(file_links)
    #upload_files(trgt_type,internal_kernel)
# Out:
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/scope/
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-172-a979e5a5df0e> in <module>
#      41     archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/" + type +  "/"
#      42     #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel
# ---> 43     file_links = get_links(archive_url,trgt_type,kernel)
#      44     #download_series(file_links)
#      45     #upload_files(trgt_type,kernel)
#
# <ipython-input-169-cdf4d8fdc265> in get_links(archive_url, trgt_type, kernel)
#      22             #newlist_match.append(names)
#      23             df=pd.DataFrame(newlist_match,columns=["kernel","File Name",'Last Modified Date'])
# ---> 24     df.to_csv(trgt_type,mode='a',index=False)
#      25 #     with pd.ExcelWriter('./report.xlsx',mode='a') as writer:
# ...

# %%
import sys
import requests 
from bs4 import BeautifulSoup 
import os
import pandas as pd
import shutil
import re

def get_links(archive_url,trgt_type,kernel):
    r = requests.get(archive_url)
    soup = BeautifulSoup(r.content,'html.parser')
    os.path
    list1 =soup.get_text().split('\n')
    r = re.compile(r".*\d{4}-\d{2}-\d{2}.*")
    newlist_match =[]
    print(archive_url)
    for names in list1:
        if bool(re.search(r".*\d{4}-\d{2}-\d{2}.*", names) and '.txt ' in names):
            names=names.strip()
            newlist_match.append([kernel,names.split("txt")[0].strip()+"txt",names.split("txt")[1].strip().split(" ")[0]])
            #newlist_match.append(names)
    if(len(newlist_match)!=0):
        df=pd.DataFrame(newlist_match,columns=["kernel","File Name",'Last Modified Date'])
        if(os.stat(trgt_type).st_size == 0):
            df.to_csv(trgt_type,mode='a',index=False)
        else:
            df.to_csv(trgt_type,mode='a',index=False,header=False)
#     with pd.ExcelWriter('./report.xlsx',mode='a') as writer:  
#         df.to_excel(writer, sheet_name=trgt_type)


args=["cPLM BH_HS_Ultrasound"]#, "SAP-MBP", "cPLM BH_HS_Ultrasound", "SAP-GTS", "SAP-MCP", "SAP-MP1"]
f= open("ValueSets.csv",'w')
f.close()
f= open("ValueMaps.csv",'w')
f.close()
f= open("Scope.csv",'w')
f.close()
for kernel in args:    
    print(kernel)
    file_types=["lookups","value_maps","scope"]
    for type in file_types:
        if type=="lookups":
            trgt_type="ValueSets.csv"
        elif type=="value_maps":
            trgt_type="ValueMaps.csv"
        elif type=="scope":
            trgt_type="Scope.csv"
#         f= open(trgt_type,'w')
#         f.close()
        if kernel=="SAP-PIL" and type=="lookups":
            sub_ker=["PIL"]
            for ker in sub_ker:
                archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
                #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
                
                    
                
                file_links = get_links(archive_url,trgt_type,ker)
                #download_series(file_links)
                #updt_kernel=kernel+"/"+ker
                #upload_files(trgt_type,updt_kernel)
                
        elif kernel=="BH_HS_Ultrasound" and type=="lookups":
            sub_ker=["PR1","MBP",""]
            for ker in sub_ker:
                archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
                #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
                
                    
                
                file_links = get_links(archive_url,trgt_type,ker)
                #download_series(file_links)
                #updt_kernel=kernel+"/"+ker
                #upload_files(trgt_type,updt_kernel)
            
        elif kernel=="SAP-PIL" and type=="value_maps":
            sub_ker=["PIL","CEP","MP1","WPA","WPX"]
            for ker in sub_ker:
                archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
                #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
                
    
                file_links = get_links(archive_url,trgt_type,ker)
                #download_series(file_links)
                #updt_kernel=kernel+"/"+ker
                #upload_files(trgt_type,updt_kernel)
            
            
        else:
            archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/" + type +  "/" 
            #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel
            file_links = get_links(archive_url,trgt_type,kernel)
            #download_series(file_links)
            #upload_files(trgt_type,kernel)
            
    
        if kernel == 'SAP-MBP' and type == 'scope':
            #check for BH_HS_Hamburg
            internal_kernel = "BH_HS_Hamburg"
            archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/" + internal_kernel  +  "/" + type+"/"
            #path_dir="/root/DQIP/dqip_data/"+trgt_type+internal_kernel
            file_links = get_links(archive_url,trgt_type,kernel)
            #download_series(file_links)
            #upload_files(trgt_type,internal_kernel)
#                 

df_scope=df.read(ValueSets.csv)
df_valset=df.read(ValueMaps.csv)
with pd.ExcelWriter('./report.xlsx',mode='a') as writer:  
         df.to_excel(writer, sheet_name=trgt_type)
# Out:
# cPLM BH_HS_Ultrasound
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/cPLM BH_HS_Ultrasound/lookups/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/cPLM BH_HS_Ultrasound/value_maps/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/cPLM BH_HS_Ultrasound/scope/

# %%
import sys
import requests 
from bs4 import BeautifulSoup 
import os
import pandas as pd
import shutil
import re

def get_links(archive_url,trgt_type,kernel):
    r = requests.get(archive_url)
    soup = BeautifulSoup(r.content,'html.parser')
    os.path
    list1 =soup.get_text().split('\n')
    r = re.compile(r".*\d{4}-\d{2}-\d{2}.*")
    newlist_match =[]
    print(archive_url)
    for names in list1:
        if bool(re.search(r".*\d{4}-\d{2}-\d{2}.*", names) and '.txt ' in names):
            names=names.strip()
            newlist_match.append([kernel,names.split("txt")[0].strip()+"txt",names.split("txt")[1].strip().split(" ")[0]])
            #newlist_match.append(names)
    if(len(newlist_match)!=0):
        df=pd.DataFrame(newlist_match,columns=["kernel","File Name",'Last Modified Date'])
        if(os.stat(trgt_type).st_size == 0):
            df.to_csv(trgt_type,mode='a',index=False)
        else:
            df.to_csv(trgt_type,mode='a',index=False,header=False)
#     with pd.ExcelWriter('./report.xlsx',mode='a') as writer:  
#         df.to_excel(writer, sheet_name=trgt_type)


args=["SAP-PIL", "SAP-MBP", "cPLM BH_HS_Ultrasound", "SAP-GTS", "SAP-MCP", "SAP-MP1"]
f= open("ValueSets.csv",'w')
f.close()
f= open("ValueMaps.csv",'w')
f.close()
f= open("Scope.csv",'w')
f.close()
for kernel in args:    
    print(kernel)
    file_types=["lookups","value_maps","scope"]
    for type in file_types:
        if type=="lookups":
            trgt_type="ValueSets.csv"
        elif type=="value_maps":
            trgt_type="ValueMaps.csv"
        elif type=="scope":
            trgt_type="Scope.csv"
#         f= open(trgt_type,'w')
#         f.close()
        if kernel=="SAP-PIL" and type=="lookups":
            sub_ker=["PIL"]
            for ker in sub_ker:
                archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
                #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
                
                    
                
                file_links = get_links(archive_url,trgt_type,ker)
                #download_series(file_links)
                #updt_kernel=kernel+"/"+ker
                #upload_files(trgt_type,updt_kernel)
                
        elif kernel=="BH_HS_Ultrasound" and type=="lookups":
            sub_ker=["PR1","MBP",""]
            for ker in sub_ker:
                archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
                #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
                
                    
                
                file_links = get_links(archive_url,trgt_type,ker)
                #download_series(file_links)
                #updt_kernel=kernel+"/"+ker
                #upload_files(trgt_type,updt_kernel)
            
        elif kernel=="SAP-PIL" and type=="value_maps":
            sub_ker=["PIL","CEP","MP1","WPA","WPX"]
            for ker in sub_ker:
                archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
                #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
                
    
                file_links = get_links(archive_url,trgt_type,ker)
                #download_series(file_links)
                #updt_kernel=kernel+"/"+ker
                #upload_files(trgt_type,updt_kernel)
            
            
        else:
            archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/" + type +  "/" 
            #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel
            file_links = get_links(archive_url,trgt_type,kernel)
            #download_series(file_links)
            #upload_files(trgt_type,kernel)
            
    
        if kernel == 'SAP-MBP' and type == 'scope':
            #check for BH_HS_Hamburg
            internal_kernel = "BH_HS_Hamburg"
            archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/" + internal_kernel  +  "/" + type+"/"
            #path_dir="/root/DQIP/dqip_data/"+trgt_type+internal_kernel
            file_links = get_links(archive_url,trgt_type,kernel)
            #download_series(file_links)
            #upload_files(trgt_type,internal_kernel)


df_scope=df.read_csv("Scope.csv")
df_valset=df.read_csv("ValueSets.csv")
df_valmap=df.read_csv("ValueMaps.csv")
with pd.ExcelWriter('./report.xlsx') as writer:  
    df_scope.to_excel(writer, sheet_name="Scope")
    df_valset.to_excel(writer, sheet_name="ValueSets")
    df_valmap.to_excel(writer, sheet_name="ValueMaps")
# Out:
# SAP-PIL
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/lookups/PIL/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/PIL/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/CEP/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/MP1/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/WPA/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/WPX/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/scope/
# SAP-MBP
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-MBP/lookups/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-MBP/value_maps/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-MBP/scope/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-MBP/BH_HS_Hamburg/scope/
# ...

# %%
trgt_type+".csv"
# Out:
# 'ValueSets.csv.csv'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-183-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import sys
import requests 
from bs4 import BeautifulSoup 
import os
import pandas as pd
import shutil
import re

def get_links(archive_url,trgt_type,kernel):
    r = requests.get(archive_url)
    soup = BeautifulSoup(r.content,'html.parser')
    os.path
    list1 =soup.get_text().split('\n')
    r = re.compile(r".*\d{4}-\d{2}-\d{2}.*")
    newlist_match =[]
    print(archive_url)
    for names in list1:
        if bool(re.search(r".*\d{4}-\d{2}-\d{2}.*", names) and '.txt ' in names):
            names=names.strip()
            newlist_match.append([kernel,names.split("txt")[0].strip()+"txt",names.split("txt")[1].strip().split(" ")[0]])
            #newlist_match.append(names)
    if(len(newlist_match)!=0):
        df=pd.DataFrame(newlist_match,columns=["kernel","File Name",'Last Modified Date'])
        if(os.stat(trgt_type).st_size == 0):
            df.to_csv(trgt_type,mode='a',index=False)
        else:
            df.to_csv(trgt_type,mode='a',index=False,header=False)
#     with pd.ExcelWriter('./report.xlsx',mode='a') as writer:  
#         df.to_excel(writer, sheet_name=trgt_type)


args=["SAP-PIL", "SAP-MBP", "cPLM","BH_HS_Ultrasound", "SAP-GTS", "SAP-MCP", "SAP-MP1"]
f= open("ValueSets.csv",'w')
f.close()
f= open("ValueMaps.csv",'w')
f.close()
f= open("Scope.csv",'w')
f.close()
for kernel in args:    
    print(kernel)
    file_types=["lookups","value_maps","scope"]
    for type in file_types:
        if type=="lookups":
            trgt_type="ValueSets.csv"
        elif type=="value_maps":
            trgt_type="ValueMaps.csv"
        elif type=="scope":
            trgt_type="Scope.csv"
#         f= open(trgt_type,'w')
#         f.close()
        if kernel=="SAP-PIL" and type=="lookups":
            sub_ker=["PIL"]
            for ker in sub_ker:
                archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
                #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
                
                    
                
                file_links = get_links(archive_url,trgt_type,ker)
                #download_series(file_links)
                #updt_kernel=kernel+"/"+ker
                #upload_files(trgt_type,updt_kernel)
                
        elif kernel=="BH_HS_Ultrasound" and type=="lookups":
            sub_ker=["PR1","MBP",""]
            for ker in sub_ker:
                archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
                #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
                
                    
                
                file_links = get_links(archive_url,trgt_type,ker)
                #download_series(file_links)
                #updt_kernel=kernel+"/"+ker
                #upload_files(trgt_type,updt_kernel)
            
        elif kernel=="SAP-PIL" and type=="value_maps":
            sub_ker=["PIL","CEP","MP1","WPA","WPX"]
            for ker in sub_ker:
                archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
                #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
                
    
                file_links = get_links(archive_url,trgt_type,ker)
                #download_series(file_links)
                #updt_kernel=kernel+"/"+ker
                #upload_files(trgt_type,updt_kernel)
            
            
        else:
            archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/" + type +  "/" 
            #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel
            file_links = get_links(archive_url,trgt_type,kernel)
            #download_series(file_links)
            #upload_files(trgt_type,kernel)
            
    
        if kernel == 'SAP-MBP' and type == 'scope':
            #check for BH_HS_Hamburg
            internal_kernel = "BH_HS_Hamburg"
            archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/" + internal_kernel  +  "/" + type+"/"
            #path_dir="/root/DQIP/dqip_data/"+trgt_type+internal_kernel
            file_links = get_links(archive_url,trgt_type,kernel)
            #download_series(file_links)
            #upload_files(trgt_type,internal_kernel)


df_scope=df.read("Scope.csv")
df_valset=df.read("ValueSets.csv")
df_valmap=df.read("ValueMaps.csv")
with pd.ExcelWriter('./report.xlsx') as writer:  
    df_scope.to_excel(writer, sheet_name="Scope")
    df_valset.to_excel(writer, sheet_name="ValueSets")
    df_valmap.to_excel(writer, sheet_name="ValueMaps")
# Out:
# SAP-PIL
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/lookups/PIL/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/PIL/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/CEP/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/MP1/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/WPA/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/WPX/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/scope/
# SAP-MBP
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-MBP/lookups/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-MBP/value_maps/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-MBP/scope/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-MBP/BH_HS_Hamburg/scope/
# ...

# %%
import sys
import requests 
from bs4 import BeautifulSoup 
import os
import pandas as pd
import shutil
import re

def get_links(archive_url,trgt_type,kernel):
    r = requests.get(archive_url)
    soup = BeautifulSoup(r.content,'html.parser')
    os.path
    list1 =soup.get_text().split('\n')
    r = re.compile(r".*\d{4}-\d{2}-\d{2}.*")
    newlist_match =[]
    print(archive_url)
    for names in list1:
        if bool(re.search(r".*\d{4}-\d{2}-\d{2}.*", names) and '.txt ' in names):
            names=names.strip()
            newlist_match.append([kernel,names.split("txt")[0].strip()+"txt",names.split("txt")[1].strip().split(" ")[0]])
            #newlist_match.append(names)
    if(len(newlist_match)!=0):
        df=pd.DataFrame(newlist_match,columns=["kernel","File Name",'Last Modified Date'])
        if(os.stat(trgt_type).st_size == 0):
            df.to_csv(trgt_type,mode='a',index=False)
        else:
            df.to_csv(trgt_type,mode='a',index=False,header=False)
#     with pd.ExcelWriter('./report.xlsx',mode='a') as writer:  
#         df.to_excel(writer, sheet_name=trgt_type)


args=["SAP-PIL", "SAP-MBP", "cPLM","BH_HS_Ultrasound", "SAP-GTS", "SAP-MCP", "SAP-MP1"]
f= open("ValueSets.csv",'w')
f.close()
f= open("ValueMaps.csv",'w')
f.close()
f= open("Scope.csv",'w')
f.close()
for kernel in args:    
    print(kernel)
    file_types=["lookups","value_maps","scope"]
    for type in file_types:
        if type=="lookups":
            trgt_type="ValueSets.csv"
        elif type=="value_maps":
            trgt_type="ValueMaps.csv"
        elif type=="scope":
            trgt_type="Scope.csv"
#         f= open(trgt_type,'w')
#         f.close()
        if kernel=="SAP-PIL" and type=="lookups":
            sub_ker=["PIL"]
            for ker in sub_ker:
                archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
                #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
                
                    
                
                file_links = get_links(archive_url,trgt_type,kernel+ "/" + ker)
                #download_series(file_links)
                #updt_kernel=kernel+"/"+ker
                #upload_files(trgt_type,updt_kernel)
                
        elif kernel=="BH_HS_Ultrasound" and type=="lookups":
            sub_ker=["PR1","MBP",""]
            for ker in sub_ker:
                archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
                #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
                
                    
                
                file_links = get_links(archive_url,trgt_type,kernel+ "/" + ker)
                #download_series(file_links)
                #updt_kernel=kernel+"/"+ker
                #upload_files(trgt_type,updt_kernel)
            
        elif kernel=="SAP-PIL" and type=="value_maps":
            sub_ker=["PIL","CEP","MP1","WPA","WPX"]
            for ker in sub_ker:
                archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/"+ type + "/" + ker +"/"
                #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
                
    
                file_links = get_links(archive_url,trgt_type,kernel+ "/" + ker)
                #download_series(file_links)
                #updt_kernel=kernel+"/"+ker
                #upload_files(trgt_type,updt_kernel)
        elif kernel=="SAP-PIL" and type=="scope":
            sub_ker=["WPP_BH_PH_CGR","WPP_BH_PH_China","WPP_BH_PH_Europe","WPP_BH_PH_SLATAM","WPQ_BH_PH_APAC","WPQ_BH_PH_China","WPQ_BH_PH_Europe","WPT_BH_PH_APAC","WPT_BH_PH_China","WPT_BH_PH_MET","WPT_BH_PH_RCA","WPT_BH_PH_RMA"]
            for ker in sub_ker:
                archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/" + ker +"/" + type + "/"
                #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel+ "/" + ker
                
    
                file_links = get_links(archive_url,trgt_type,kernel+ "/" + ker)
                #download_series(file_links)
                #updt_kernel=kernel+"/"+ker
                #upload_files(trgt_type,updt_kernel)
            
            
        else:
            archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/" + type +  "/" 
            #path_dir="/root/DQIP/dqip_data/"+trgt_type+kernel
            file_links = get_links(archive_url,trgt_type,kernel)
            #download_series(file_links)
            #upload_files(trgt_type,kernel)
            
    
        if kernel == 'SAP-MBP' and type == 'scope':
            #check for BH_HS_Hamburg
            internal_kernel = "BH_HS_Hamburg"
            archive_url="http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/" +kernel+ "/" + internal_kernel  +  "/" + type+"/"
            #path_dir="/root/DQIP/dqip_data/"+trgt_type+internal_kernel
            file_links = get_links(archive_url,trgt_type,internal_kernel)
            #download_series(file_links)
            #upload_files(trgt_type,internal_kernel)
            #download_series(file_links)
            #upload_files(trgt_type,internal_kernel)


df_scope=pd.read_csv("Scope.csv")
df_valset=pd.read_csv("ValueSets.csv")
df_valmap=pd.read_csv("ValueMaps.csv")
with pd.ExcelWriter('./Product_Migration_required_files.xlsx') as writer:  
    df_scope.to_excel(writer, sheet_name="Scope")
    df_valset.to_excel(writer, sheet_name="ValueSets")
    df_valmap.to_excel(writer, sheet_name="ValueMaps")
# Out:
# SAP-PIL
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/lookups/PIL/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/PIL/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/CEP/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/MP1/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/WPA/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/value_maps/WPX/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/scope/WPP_BH_PH_CGR/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/scope/WPP_BH_PH_China/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/scope/WPP_BH_PH_Europe/
# http://pww.kit.bbl.ms.philips.com:7080/Data-Quality-Reports/DQIP/SAP-PIL/scope/WPP_BH_PH_SLATAM/
# ...
